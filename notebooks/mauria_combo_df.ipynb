# %%
import pandas as pd
# import polars as pl
import sqlite3

# %% [markdown]
# Cleaning strategy for NPPES file:
# - read in only columns relevant to this project
# - process taxonomy code columns to determine primary
# - drop taxonomy code columns (keep only added primary code column)
# - join classification crosswalk to get taxonomy name
# - join CBSA crosswalk to match provider on zip code
# - make column names better for SQL
# - put into sqlite

# %%
# generate list of taxonomy columns
tax_cols = []

for i in range(1, 16):
    switch_col_name = f'Healthcare Provider Primary Taxonomy Switch_{i}'
    tax_cols.append(switch_col_name)
    code_col_name = f'Healthcare Provider Taxonomy Code_{i}'
    tax_cols.append(code_col_name)

# other relevant columns
cols = ['NPI', 'Entity Type Code', 'Provider Organization Name (Legal Business Name)', 'Provider Last Name (Legal Name)',
        'Provider First Name', 'Provider Middle Name', 'Provider Name Prefix Text', 'Provider Name Suffix Text',
        'Provider Credential Text', 'Provider First Line Business Practice Location Address',
        'Provider Second Line Business Practice Location Address', 'Provider Business Practice Location Address City Name',
        'Provider Business Practice Location Address State Name', 'Provider Business Practice Location Address Postal Code']

# combine column name lists
cols.extend(tax_cols)

# %%
npi = pd.read_csv('../data/npidata_pfile_20050523-20240211.csv', usecols = cols, dtype = str)

# %%
# pull primary taxonomy codes into one column
# modify to take first 'X' if there is no 'Y'
# add unified flag column (X or Y)
# pull all rows with 'X' into separate dataset (in addition to main)
# don't drop non-flag

def extract_taxonomy_code(row):

#    row['extracted_switch_col'] = None

    # to catch all rows with a 'Y' switch
    for i in range(1, 16):
        switch_col_name = f'Healthcare Provider Primary Taxonomy Switch_{i}'
        if row[switch_col_name] == 'Y':
            code_col_name = f'Healthcare Provider Taxonomy Code_{i}'
            # row['extracted_switch_col'] = 'Y'
            return row[code_col_name]
        
    # if no 'Y' switch was found, capture first 'X'
    # this second chunk makes it incredibly inefficient, find a better way
    # if row['extracted_switch_col'] is None:
    #     for i in range(1, 16):
    #         switch_col_name = f'Healthcare Provider Primary Taxonomy Switch_{i}'
    #         if row[switch_col_name] == 'X':
    #             code_col_name = f'Healthcare Provider Taxonomy Code_{i}'
    #             if 'extracted_switch_col' not in row:
    #                 row['extracted_switch_col'] = 'X'
    #                 return row[code_col_name]
    
    return None # for rows with no 'Y' or 'X' switch

# %%
npi['extracted_taxonomy_code'] = npi.apply(extract_taxonomy_code, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 npi['extracted_taxonomy_code'] = npi.apply(extract_taxonomy_code, axis = 1)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[4], line 14, in extract_taxonomy_code(row)
#      12 for i in range(1, 16):
#      13     switch_col_name = f'Healthcare Provider Primary Taxonomy Switch_{i}'
# ---> 14     if row[switch_col_name] == 'Y':
#      15         code_col_name = f'Healthcare Provider Taxonomy Code_{i}'
#      16         # row['extracted_switch_col'] = 'Y'
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:968, in Series.__getitem__(self, key)
#     966 def __getitem__(self, key):
#     967     check_deprecated_indexers(key)
# --> 968     key = com.apply_if_callable(key, self)
#     970     if key is Ellipsis:
#     971         return self
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/common.py:362, in apply_if_callable(maybe_callable, obj, **kwargs)
#     355     # everything failed (probably because the argument
#     356     # wasn't actually callable); we return None
#     357     # instead of the empty string in this case to allow
#     358     # distinguishing between no name and a name of ''
#     359     return None
# --> 362 def apply_if_callable(maybe_callable, obj, **kwargs):
#     363     """
#     364     Evaluate possibly callable input using obj and kwargs if it is callable,
#     365     otherwise return as it is.
#    (...)
#     371     **kwargs
#     372     """
#     373     if callable(maybe_callable):
#
# KeyboardInterrupt:

# %%
npi.head()

# %%
npi.info()
# having doublechecked the values in the switch columns, it appears that there are rows with no 'Y' switch
# should those rows be dropped, or possibly the taxonomy code in Code_1 could be inferred to be the correct code?
# some rows with no 'Y' switch have one or more 'X' switches

# %%
npi['Provider Business Practice Location Address Postal Code'].value_counts(dropna = False)

# %%
# truncate zipcode to 5 digits (match CBSA crosswalk)
npi['Provider Business Practice Location Address Postal Code'] = npi['Provider Business Practice Location Address Postal Code'].str.slice(0, 5)

# %%
# if we decide to drop rows with no 'Y' switch
# npi.dropna(subset = ['extracted_taxonomy_code'], inplace = True)

# %%
# drop taxonomy columns
npi = npi.drop(tax_cols, axis = 1)

# %%
# convert column names to better format
npi.columns = [x.lower().replace(' ', '_').replace('(', '').replace(')', '') for x in npi.columns]

# %%
# npi data to sqlite
# create sqlite database
db = sqlite3.connect('../data/provider.sqlite')

npi.to_sql('npi',
           db,
           if_exists = 'replace',
           index = False)

db.close()

# %%
#create indexes on npi-containing columns for faster queries
db = sqlite3.connect('../data/provider.sqlite')

db.execute('CREATE INDEX npi_index ON npi(npi)')
db.execute('CREATE INDEX to_npi ON hop(to_npi)')
db.execute('CREATE INDEX from_npi ON hop(from_npi)')
db.close()

# %%
# read in classification crosswalk
class_cross = pd.read_csv('../data/nucc_taxonomy_240.csv', usecols = ['Code', 'Grouping', 'Classification', 'Display Name'])

# %%
class_cross.head()

# %%
# convert column names to better format
class_cross.columns = [x.lower().replace(' ', '_') for x in class_cross.columns]

# %%
# classification crosswalk data to sqlite
# create sqlite database
db = sqlite3.connect('../data/provider.sqlite')

class_cross.to_sql('class_cross',
           db,
           if_exists = 'replace',
           index = False)

db.close()

# %%
# read in CBSA crosswalk

cbsa_cross = pd.read_csv('../data/ZIP_CBSA_122023.xlsx - Export Worksheet.csv', usecols = ['ZIP', 'CBSA', 'USPS_ZIP_PREF_CITY', 'USPS_ZIP_PREF_STATE'])

# %%
cbsa_cross.head()

# %%
cbsa_cross.info()

# %%
# convert column names to better format
cbsa_cross.columns = [x.lower().replace(' ', '_') for x in cbsa_cross.columns]

# %%
# CBSA crosswalk data to sqlite
# create sqlite database
db = sqlite3.connect('../data/provider.sqlite')

cbsa_cross.to_sql('cbsa_cross',
           db,
           if_exists = 'replace',
           index = False)

db.close()

# %%
# read in hop teaming data
hop = pd.read_csv('../data/DocGraph_Hop_Teaming_2018.csv')

# %%
hop.head()

# %%
hop.info()

# %%
hop = hop[hop['transaction_count'] >= 50]

# %%
hop = hop[hop['average_day_wait'] <= 50]

# %%
hop.head()

# %%
# hop data to sqlite
# create sqlite database
db = sqlite3.connect('../data/provider.sqlite')

hop.to_sql('hop',
           db,
           if_exists = 'replace',
           index = False)

db.close()

# %%
# building table for hospitals
# cbsa = 34980, either hardcode or use a cte to get the value where usps_zip_pref_city = "NASHVILLE" and usps_zip_pref_state = "TN" (filter based on referee cbsa)
query = """
SELECT npi,
    entity_type_code AS entity_type,
    provider_organization_name_legal_business_name AS provider_org_name,
    provider_first_line_business_practice_location_address AS provider_address_1,
    provider_second_line_business_practice_location_address AS provider_address_2,
    provider_business_practice_location_address_city_name AS provider_city,
    provider_business_practice_location_address_state_name AS provider_state,
    provider_business_practice_location_address_postal_code AS provider_post_code,
    extracted_taxonomy_code AS tax_code,
    grouping AS code_group,
    classification AS code_classification,
    display_name AS code_display_name
FROM npi AS n
LEFT JOIN class_cross AS c
    ON n.extracted_taxonomy_code = c.code
LEFT JOIN cbsa_cross cb
    ON n.provider_business_practice_location_address_postal_code = cb.zip
WHERE entity_type_code = 2
    AND cbsa = 34980;
"""

with sqlite3.connect('../data/provider.sqlite') as db: 
    hosp_sqlite = pd.read_sql(query, db)

hosp_sqlite.head()
# Out:
#           npi entity_type                  provider_org_name  \
# 0  1881697092           2                          RHS, INC.
# 1  1326041534           2  MURFREESBORO CONVALESCENT SERVICE
# 2  1063415834           2         ADVANCED DIABETIC SERVICES
# 3  1538162334           2     TENNESSEE IMAGING ALLIANCE LLC
# 4  1245233220           2      NORTHRIDGE SURGERY CENTER, LP
#
#        provider_address_1 provider_address_2 provider_city provider_state  \
# 0       1330 TROTWOOD AVE               None      COLUMBIA             TN
# 1     4428 LASCASSAS PIKE               None  MURFREESBORO             TN
# 2    151 HERITAGE PARK DR            STE 403  MURFREESBORO             TN
# 3  2628 N MOUNT JULIET RD               None  MOUNT JULIET             TN
# 4    601 SAUNDERSVILLE RD               None       MADISON             TN
#
#   provider_post_code    tax_code                         code_group  \
# 0              38401  332B00000X                          Suppliers
# 1              37130  341600000X            Transportation Services
# 2              37129  332B00000X                          Suppliers
# 3              37122  261QR0208X  Ambulatory Health Care Facilities
# 4              37075  261QA1903X  Ambulatory Health Care Facilities
#
#                             code_classification  \
# 0  Durable Medical Equipment & Medical Supplies
# 1                                     Ambulance
# 2  Durable Medical Equipment & Medical Supplies
# 3                                 Clinic/Center
# 4                                 Clinic/Center
#
#                               code_display_name
# 0  Durable Medical Equipment & Medical Supplies
# 1                                     Ambulance
# 2  Durable Medical Equipment & Medical Supplies
# 3                Mobile Radiology Clinic/Center
# 4             Ambulatory Surgical Clinic/Center

# %%
#overview of entity categories
unique_code_group = hosp_sqlite.code_group.unique()

print(unique_code_group)
# Out:
# ['Suppliers' 'Transportation Services' 'Ambulatory Health Care Facilities'
#  'Allopathic & Osteopathic Physicians' 'Agencies' None
#  'Other Service Providers' 'Laboratories'
#  'Nursing & Custodial Care Facilities'
#  'Respiratory, Developmental, Rehabilitative and Restorative Service Providers'
#  'Hospitals' 'Residential Treatment Facilities'
#  'Eye and Vision Services Providers' 'Dental Providers'
#  'Pharmacy Service Providers' 'Hospital Units'
#  'Physician Assistants & Advanced Practice Nursing Providers'
#  'Behavioral Health & Social Service Providers'
#  'Podiatric Medicine & Surgery Service Providers'
#  'Technologists, Technicians & Other Technical Service Providers'
#  'Chiropractic Providers' 'Nursing Service Providers'
#  'Speech, Language and Hearing Service Providers'
#  'Managed Care Organizations' 'Emergency Medical Service Providers'
#  'Nursing Service Related Providers'
#  'Dietary & Nutritional Service Providers' 'Respite Care Facility'
#  'Student, Health Care']

# %%
#left joining hop data

query = """
SELECT npi,
    entity_type_code AS entity_type,
    provider_organization_name_legal_business_name AS provider_org_name,
    provider_first_line_business_practice_location_address AS provider_address_1,
    provider_second_line_business_practice_location_address AS provider_address_2,
    provider_business_practice_location_address_city_name AS provider_city,
    provider_business_practice_location_address_state_name AS provider_state,
    provider_business_practice_location_address_postal_code AS provider_post_code,
    extracted_taxonomy_code AS tax_code,
    grouping AS code_group,
    classification AS code_classification,
    display_name AS code_display_name,
    from_npi as referred_from,
    patient_count,
    transaction_count,
    average_day_wait,
    std_day_wait
    
    
FROM npi AS n
LEFT JOIN class_cross AS c
    ON n.extracted_taxonomy_code = c.code
LEFT JOIN cbsa_cross cb
    ON n.provider_business_practice_location_address_postal_code = cb.zip
LEFT JOIN hop
    ON n.npi = hop.to_npi
WHERE entity_type_code = 2
    AND cbsa = 34980;
"""

with sqlite3.connect('../data/provider.sqlite') as db: 
    hosp_hop = pd.read_sql(query, db)

hosp_hop.head()
# Out:
#           npi entity_type                  provider_org_name  \
# 0  1881697092           2                          RHS, INC.
# 1  1326041534           2  MURFREESBORO CONVALESCENT SERVICE
# 2  1063415834           2         ADVANCED DIABETIC SERVICES
# 3  1538162334           2     TENNESSEE IMAGING ALLIANCE LLC
# 4  1245233220           2      NORTHRIDGE SURGERY CENTER, LP
#
#        provider_address_1 provider_address_2 provider_city provider_state  \
# 0       1330 TROTWOOD AVE               None      COLUMBIA             TN
# 1     4428 LASCASSAS PIKE               None  MURFREESBORO             TN
# 2    151 HERITAGE PARK DR            STE 403  MURFREESBORO             TN
# 3  2628 N MOUNT JULIET RD               None  MOUNT JULIET             TN
# 4    601 SAUNDERSVILLE RD               None       MADISON             TN
#
#   provider_post_code    tax_code                         code_group  \
# 0              38401  332B00000X                          Suppliers
# 1              37130  341600000X            Transportation Services
# 2              37129  332B00000X                          Suppliers
# 3              37122  261QR0208X  Ambulatory Health Care Facilities
# 4              37075  261QA1903X  Ambulatory Health Care Facilities
#
#                             code_classification  \
# 0  Durable Medical Equipment & Medical Supplies
# 1                                     Ambulance
# 2  Durable Medical Equipment & Medical Supplies
# 3                                 Clinic/Center
# 4                                 Clinic/Center
#
#                               code_display_name  referred_from  patient_count  \
# 0  Durable Medical Equipment & Medical Supplies            NaN            NaN
# 1                                     Ambulance            NaN            NaN
# 2  Durable Medical Equipment & Medical Supplies            NaN            NaN
# 3                Mobile Radiology Clinic/Center            NaN            NaN
# 4             Ambulatory Surgical Clinic/Center   1.518961e+09          264.0
#
#    transaction_count  average_day_wait  std_day_wait
# 0                NaN               NaN           NaN
# 1                NaN               NaN           NaN
# 2                NaN               NaN           NaN
# 3                NaN               NaN           NaN
# 4              451.0             0.929        10.235

# %%
hosp_sqlite.shape
# Out:
# (9841, 12)

# %%
hosp_hop.shape
# Out:
# (131530, 17)

# %%
#removing NaNs fixed issue of referred_from showing up in scientific notation

# %%
#tried to remove NaNs but actually I think I just need to right join instead. No, INNER JOIN
hosp_hop_nonan = hosp_hop[~hosp_hop['referred_from'].isna()]
hosp_hop_nonan
# Out:
#                npi entity_type  \
# 4       1245233220           2
# 5       1245233220           2
# 6       1245233220           2
# 7       1245233220           2
# 8       1245233220           2
# ...            ...         ...
# 128771  1225517014           2
# 128772  1225517014           2
# 128773  1225517014           2
# 128785  1417438706           2
# 128786  1417438706           2
#
#                                         provider_org_name  \
# 4                           NORTHRIDGE SURGERY CENTER, LP
# 5                           NORTHRIDGE SURGERY CENTER, LP
# 6                           NORTHRIDGE SURGERY CENTER, LP
# 7                           NORTHRIDGE SURGERY CENTER, LP
# 8                           NORTHRIDGE SURGERY CENTER, LP
# ...                                                   ...
# 128771  HOSPITALIST MEDICINE PHYSICIANS OF OHIO - COLU...
# 128772  HOSPITALIST MEDICINE PHYSICIANS OF OHIO - COLU...
# 128773  HOSPITALIST MEDICINE PHYSICIANS OF OHIO - COLU...
# 128785                  BECKWITH EMERGENCY PHYSICIAN PLLC
# 128786                  BECKWITH EMERGENCY PHYSICIAN PLLC
#
#                provider_address_1 provider_address_2 provider_city  \
# 4            601 SAUNDERSVILLE RD               None       MADISON
# 5            601 SAUNDERSVILLE RD               None       MADISON
# 6            601 SAUNDERSVILLE RD               None       MADISON
# 7            601 SAUNDERSVILLE RD               None       MADISON
# 8            601 SAUNDERSVILLE RD               None       MADISON
# ...                           ...                ...           ...
# 128771  5410 MARYLAND WAY STE 300               None     BRENTWOOD
# 128772  5410 MARYLAND WAY STE 300               None     BRENTWOOD
# 128773  5410 MARYLAND WAY STE 300               None     BRENTWOOD
# 128785           5052 BECKWITH RD               None     MT JULIET
# 128786           5052 BECKWITH RD               None     MT JULIET
#
#        provider_state provider_post_code    tax_code  \
# 4                  TN              37075  261QA1903X
# 5                  TN              37075  261QA1903X
# 6                  TN              37075  261QA1903X
# 7                  TN              37075  261QA1903X
# 8                  TN              37075  261QA1903X
# ...               ...                ...         ...
# 128771             TN              37027  207R00000X
# 128772             TN              37027  207R00000X
# 128773             TN              37027  207R00000X
# 128785             TN              37122  207P00000X
# 128786             TN              37122  207P00000X
#
#                                  code_group code_classification  \
# 4         Ambulatory Health Care Facilities       Clinic/Center
# 5         Ambulatory Health Care Facilities       Clinic/Center
# 6         Ambulatory Health Care Facilities       Clinic/Center
# 7         Ambulatory Health Care Facilities       Clinic/Center
# 8         Ambulatory Health Care Facilities       Clinic/Center
# ...                                     ...                 ...
# 128771  Allopathic & Osteopathic Physicians   Internal Medicine
# 128772  Allopathic & Osteopathic Physicians   Internal Medicine
# 128773  Allopathic & Osteopathic Physicians   Internal Medicine
# 128785  Allopathic & Osteopathic Physicians  Emergency Medicine
# 128786  Allopathic & Osteopathic Physicians  Emergency Medicine
#
#                         code_display_name  referred_from  patient_count  \
# 4       Ambulatory Surgical Clinic/Center   1.518961e+09          264.0
# 5       Ambulatory Surgical Clinic/Center   1.538154e+09           89.0
# 6       Ambulatory Surgical Clinic/Center   1.801075e+09          169.0
# 7       Ambulatory Surgical Clinic/Center   1.427099e+09          122.0
# 8       Ambulatory Surgical Clinic/Center   1.336416e+09           74.0
# ...                                   ...            ...            ...
# 128771        Internal Medicine Physician   1.386930e+09           85.0
# 128772        Internal Medicine Physician   1.396836e+09          110.0
# 128773        Internal Medicine Physician   1.396855e+09           42.0
# 128785       Emergency Medicine Physician   1.861478e+09           48.0
# 128786       Emergency Medicine Physician   1.982650e+09           56.0
#
#         transaction_count  average_day_wait  std_day_wait
# 4                   451.0             0.929        10.235
# 5                    92.0            47.554        81.779
# 6                   193.0             0.000         0.000
# 7                   133.0             0.000         0.000
# 8                    76.0             0.000         0.000
# ...                   ...               ...           ...
# 128771               89.0             5.303        13.041
# 128772              218.0            28.610        60.571
# 128773               55.0            38.273        76.692
# 128785               50.0            11.500        36.757
# 128786               61.0             0.000         0.000
#
# [123310 rows x 17 columns]

# %%
#INNER joining hop data
query = """
SELECT npi,
    entity_type_code AS entity_type,
    provider_organization_name_legal_business_name AS provider_org_name,
    provider_first_line_business_practice_location_address AS provider_address_1,
    provider_second_line_business_practice_location_address AS provider_address_2,
    provider_business_practice_location_address_city_name AS provider_city,
    provider_business_practice_location_address_state_name AS provider_state,
    provider_business_practice_location_address_postal_code AS provider_post_code,
    extracted_taxonomy_code AS tax_code,
    grouping AS code_group,
    classification AS code_classification,
    display_name AS code_display_name,
    from_npi as referred_from,
    patient_count,
    transaction_count,
    average_day_wait,
    std_day_wait
    
    
FROM npi AS n
LEFT JOIN class_cross AS c
    ON n.extracted_taxonomy_code = c.code
LEFT JOIN cbsa_cross cb
    ON n.provider_business_practice_location_address_postal_code = cb.zip
INNER JOIN hop
    ON n.npi = hop.to_npi
WHERE entity_type_code = 2
    AND cbsa = 34980;
"""

with sqlite3.connect('../data/provider.sqlite') as db: 
    hosp_hop_right = pd.read_sql(query, db)

hosp_hop_right.head()
# Out:
#           npi entity_type              provider_org_name  \
# 0  1245233220           2  NORTHRIDGE SURGERY CENTER, LP
# 1  1245233220           2  NORTHRIDGE SURGERY CENTER, LP
# 2  1245233220           2  NORTHRIDGE SURGERY CENTER, LP
# 3  1245233220           2  NORTHRIDGE SURGERY CENTER, LP
# 4  1245233220           2  NORTHRIDGE SURGERY CENTER, LP
#
#      provider_address_1 provider_address_2 provider_city provider_state  \
# 0  601 SAUNDERSVILLE RD               None       MADISON             TN
# 1  601 SAUNDERSVILLE RD               None       MADISON             TN
# 2  601 SAUNDERSVILLE RD               None       MADISON             TN
# 3  601 SAUNDERSVILLE RD               None       MADISON             TN
# 4  601 SAUNDERSVILLE RD               None       MADISON             TN
#
#   provider_post_code    tax_code                         code_group  \
# 0              37075  261QA1903X  Ambulatory Health Care Facilities
# 1              37075  261QA1903X  Ambulatory Health Care Facilities
# 2              37075  261QA1903X  Ambulatory Health Care Facilities
# 3              37075  261QA1903X  Ambulatory Health Care Facilities
# 4              37075  261QA1903X  Ambulatory Health Care Facilities
#
#   code_classification                  code_display_name  referred_from  \
# 0       Clinic/Center  Ambulatory Surgical Clinic/Center     1518961176
# 1       Clinic/Center  Ambulatory Surgical Clinic/Center     1538153937
# 2       Clinic/Center  Ambulatory Surgical Clinic/Center     1801075247
# 3       Clinic/Center  Ambulatory Surgical Clinic/Center     1427098912
# 4       Clinic/Center  Ambulatory Surgical Clinic/Center     1336415819
#
#    patient_count  transaction_count  average_day_wait  std_day_wait
# 0            264                451             0.929        10.235
# 1             89                 92            47.554        81.779
# 2            169                193             0.000         0.000
# 3            122                133             0.000         0.000
# 4             74                 76             0.000         0.000

# %%
hosp_hop_right.shape
# Out:
# (123310, 17)

# %%
#filter data by higher transaction count with same avg day wait to illuminate larger facilities(receiving more referrals)
hop_filtered = hosp_hop_right[(hosp_hop_right['transaction_count'] >= 1500) & (hosp_hop_right['average_day_wait'] <= 50)]
hop_filtered.shape
# Out:
# (3252, 17)

# %%
#how many unique to: npis?
hop_filtered.npi.nunique()
# Out:
# 366

# %%
#how many unique org names?
hop_filtered.provider_org_name.nunique()
# Out:
# 315

# %%
#how many unique from: npis? this explains discrepancy in row between hop_filtered and louvain
hop_filtered.referred_from.nunique()
# Out:
# 1361

# %%
#export csv to put into Neo4j
hop_filtered.to_csv('../data/hop_filtered.csv', index= False)

# %%
#read in louvain output from Neo4j
louvain = pd.read_csv('../data/hop_filtered_louvain.csv', dtype = str)
louvain.head()
# Out:
#            name communityId
# 0  "1003028770"          60
# 1  "1003059247"         759
# 2  "1003230236"         105
# 3  "1003283201"         362
# 4  "1003819277"         105

# %%
#strip quotes to prepare for join
louvain['name'] = louvain['name'].str.strip('\"')
louvain
# Out:
#             name communityId
# 0     1003028770          60
# 1     1003059247         759
# 2     1003230236         105
# 3     1003283201         362
# 4     1003819277         105
# ...          ...         ...
# 1499  1992756779          46
# 1500  1992776405          25
# 1501  1992893416          28
# 1502  1992897326         335
# 1503  1992960298         105
#
# [1504 rows x 2 columns]

# %%
# inner merge hosp_hop_right onto louvain
# louvain_info = pd.merge(louvain, hosp_hop_right, left_on= 'name', right_on= 'npi', how= 'inner')
# louvain_info.head()
# Out:
#          name communityId         npi entity_type  \
# 0  1003028770          60  1003028770           2
# 1  1003028770          60  1003028770           2
# 2  1003028770          60  1003028770           2
# 3  1003028770          60  1003028770           2
# 4  1003028770          60  1003028770           2
#
#              provider_org_name provider_address_1 provider_address_2  \
# 0  SPRING HILL DERMATOLOGY PLC  1229 RESERVE BLVD          SUITE 200
# 1  SPRING HILL DERMATOLOGY PLC  1229 RESERVE BLVD          SUITE 200
# 2  SPRING HILL DERMATOLOGY PLC  1229 RESERVE BLVD          SUITE 200
# 3  SPRING HILL DERMATOLOGY PLC  1229 RESERVE BLVD          SUITE 200
# 4  SPRING HILL DERMATOLOGY PLC  1229 RESERVE BLVD          SUITE 200
#
#   provider_city provider_state provider_post_code    tax_code  \
# 0   SPRING HILL             TN              37174  207N00000X
# 1   SPRING HILL             TN              37174  207N00000X
# 2   SPRING HILL             TN              37174  207N00000X
# 3   SPRING HILL             TN              37174  207N00000X
# 4   SPRING HILL             TN              37174  207N00000X
#
#                             code_group code_classification  \
# 0  Allopathic & Osteopathic Physicians         Dermatology
# 1  Allopathic & Osteopathic Physicians         Dermatology
# 2  Allopathic & Osteopathic Physicians         Dermatology
# 3  Allopathic & Osteopathic Physicians         Dermatology
# 4  Allopathic & Osteopathic Physicians         Dermatology
#
#        code_display_name  referred_from  patient_count  transaction_count  \
# 0  Dermatology Physician     1518143122             29                 50
# 1  Dermatology Physician     1538234935             42                 66
# 2  Dermatology Physician     1790170389             43                 54
# 3  Dermatology Physician     1801990049             98                130
# 4  Dermatology Physician     1811955917             79                 96
#
#    average_day_wait  std_day_wait
# 0            32.280        57.153
# 1            38.439        54.733
# 2            37.537        45.100
# 3            48.631        59.293
# 4            48.281        52.218

# %%
#hmm, why am I getting so many rows? should be 1504 right? same as louvain
# louvain_info.shape
# Out:
# (103391, 19)

# %%
#change column name to join instead of merging and creating a million columns
louvain = louvain.rename(columns={'name': 'npi'})
louvain
# Out:
#              npi communityId
# 0     1003028770          60
# 1     1003059247         759
# 2     1003230236         105
# 3     1003283201         362
# 4     1003819277         105
# ...          ...         ...
# 1499  1992756779          46
# 1500  1992776405          25
# 1501  1992893416          28
# 1502  1992897326         335
# 1503  1992960298         105
#
# [1504 rows x 2 columns]

# %%
#left join louvain to hosp_hop_right
louvain_info = louvain.join(hosp_hop_right, on= "npi", how= 'left')
louvain_info
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 2
#       1 #left join louvain to hosp_hop_right
# ----> 2 louvain_info = louvain.join(hosp_hop_right, on= "npi", how= 'left')
#       3 louvain_info
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:9979, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9816 def join(
#    9817     self,
#    9818     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9824     validate: str | None = None,
#    9825 ) -> DataFrame:
#    9826     """
#    9827     Join columns of another DataFrame.
#    9828
#    (...)
#    9977     5  K1  A5   B1
#    9978     """
# -> 9979     return self._join_compat(
#    9980         other,
#    9981         on=on,
#    9982         how=how,
#    9983         lsuffix=lsuffix,
#    9984         rsuffix=rsuffix,
#    9985         sort=sort,
#    9986         validate=validate,
#    9987     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10018, in DataFrame._join_compat(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10008     if how == "cross":
#   10009         return merge(
#   10010             self,
#   10011             other,
#    (...)
#   10016             validate=validate,
#   10017         )
# > 10018     return merge(
#   10019         self,
#   10020         other,
#   10021         left_on=on,
#   10022         how=how,
#   10023         left_index=on is None,
#   10024         right_index=True,
#   10025         suffixes=(lsuffix, rsuffix),
#   10026         sort=sort,
#   10027         validate=validate,
#   10028     )
#   10029 else:
#   10030     if on is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:707, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
#     703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
# --> 707 self._maybe_coerce_merge_keys()
#     709 # If argument passed to validate,
#     710 # check if columns specified as unique
#     711 # are in fact unique.
#     712 if validate is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:1340, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1334     # unless we are merging non-string-like with string-like
#    1335     elif (
#    1336         inferred_left in string_types and inferred_right not in string_types
#    1337     ) or (
#    1338         inferred_right in string_types and inferred_left not in string_types
#    1339     ):
# -> 1340         raise ValueError(msg)
#    1342 # datetimelikes must match exactly
#    1343 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
hosp_hop_right.dtypes
# Out:
# npi                     object
# entity_type             object
# provider_org_name       object
# provider_address_1      object
# provider_address_2      object
# provider_city           object
# provider_state          object
# provider_post_code      object
# tax_code                object
# code_group              object
# code_classification     object
# code_display_name       object
# referred_from            int64
# patient_count            int64
# transaction_count        int64
# average_day_wait       float64
# std_day_wait           float64
# dtype: object

# %%
louvain.dtypes
# Out:
# npi            object
# communityId    object
# dtype: object

# %%
#what gives? my key columns are both objects. investigate tomorrow
